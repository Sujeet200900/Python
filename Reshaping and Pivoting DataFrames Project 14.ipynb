# %%
#Transpose-vertical To horizental

grouping_Data
#stack-
#unstack
#pivot-
#Pivot_table-pivot_table or crosstab to build a summary table
#Crosstab-The pandas crosstab function builds a cross-tabulation table that can show the frequency with which certain groups of data


#Melt-Column-tranform_in Row_label

More_example:-https://pbpython.com/pandas-crosstab.html

# %%
import pandas as pd

# %%
titanic=pd.read_csv("C://Users//HP//Documents//Basic_Pandas//titanic.csv")

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic.T
# Out:
#            0        1       2       3     4       5        6       7    \
# survived     0        1       1       1     0       0        0       0
# pclass       3        1       3       1     3       3        1       3
# sex       male   female  female  female  male    male     male    male
# age       22.0     38.0    26.0    35.0  35.0     NaN     54.0     2.0
# sibsp        1        1       0       1     0       0        0       3
# parch        0        0       0       0     0       0        0       1
# fare      7.25  71.2833   7.925    53.1  8.05  8.4583  51.8625  21.075
# embarked     S        C       S       S     S       Q        S       S
# deck       NaN        C     NaN       C   NaN     NaN        E     NaN
#
#               8        9    ...     881      882   883   884     885   886  \
# survived        1        1  ...       0        0     0     0       0     0
# pclass          3        2  ...       3        3     2     3       3     2
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic.survived.mean()
# Out:
# 0.3838383838383838

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic.groupby(['sex','pclass']).survived.mean()
# Out:
# sex     pclass
# female  1         0.968085
#         2         0.921053
#         3         0.500000
# male    1         0.368852
#         2         0.157407
#         3         0.135447
# Name: survived, dtype: float64

# %%
titanic.groupby(['sex','pclass']).survived.mean().unstack()
# Out:
# pclass         1         2         3
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
titanic.groupby(['sex','pclass']).survived.mean().unstack().T
# Out:
# sex       female      male
# pclass
# 1       0.968085  0.368852
# 2       0.921053  0.157407
# 3       0.500000  0.135447

# %%
summer=pd.read_csv('C://Users//HP//Documents//Basic_Pandas//summer.csv')

# %%
summer
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
summer1=summer[['Country','Medal','Gender']]

# %%
summer2=summer1.groupby(['Country','Medal'])['Gender'].count().reset_index()

# %%
summer2.rename(columns ={'Gender':'Count'},inplace=True)

# %%
summer2
# Out:
#     Country   Medal  Count
# 0       AFG  Bronze      2
# 1       AHO  Silver      1
# 2       ALG  Bronze      8
# 3       ALG    Gold      5
# 4       ALG  Silver      2
# ..      ...     ...    ...
# 342     ZIM    Gold     18
# 343     ZIM  Silver      4
# 344     ZZX  Bronze     10
# 345     ZZX    Gold     23
# 346     ZZX  Silver     15
#
# [347 rows x 3 columns]

# %%
summer2.pivot(index="Country", columns="Medal", values="Count").fillna(0)
# Out:
# Medal    Bronze   Gold  Silver
# Country
# AFG         2.0    0.0     0.0
# AHO         0.0    0.0     1.0
# ALG         8.0    5.0     2.0
# ANZ         5.0   20.0     4.0
# ARG        91.0   69.0    99.0
# ...         ...    ...     ...
# VIE         0.0    0.0     2.0
# YUG       118.0  143.0   174.0
# ZAM         1.0    0.0     1.0
# ZIM         1.0   18.0     4.0
# ZZX        10.0   23.0    15.0
#
# [147 rows x 3 columns]

# %%
summer2.pivot_table(index="Country", columns="Medal", values="Count", aggfunc="mean").fillna(0)
# Out:
# Medal    Bronze   Gold  Silver
# Country
# AFG         2.0    0.0     0.0
# AHO         0.0    0.0     1.0
# ALG         8.0    5.0     2.0
# ANZ         5.0   20.0     4.0
# ARG        91.0   69.0    99.0
# ...         ...    ...     ...
# VIE         0.0    0.0     2.0
# YUG       118.0  143.0   174.0
# ZAM         1.0    0.0     1.0
# ZIM         1.0   18.0     4.0
# ZZX        10.0   23.0    15.0
#
# [147 rows x 3 columns]

# %%
summer2.pivot_table(index="Country", columns="Medal", values="Count", aggfunc="sum",fill_value=0, margins=True)
# Out:
# Medal    Bronze   Gold  Silver    All
# Country
# AFG           2      0       0      2
# AHO           0      0       1      1
# ALG           8      5       2     15
# ANZ           5     20       4     29
# ARG          91     69      99    259
# ...         ...    ...     ...    ...
# YUG         118    143     174    435
# ZAM           1      0       1      2
# ZIM           1     18       4     23
# ZZX          10     23      15     48
# All       10369  10484   10308  31161
#
# [148 rows x 4 columns]

# %%
pd.crosstab(titanic.sex,titanic.pclass, margins=True,normalize=True)
# Out:
# pclass         1         2         3       All
# sex
# female  0.105499  0.085297  0.161616  0.352413
# male    0.136925  0.121212  0.389450  0.647587
# All     0.242424  0.206510  0.551066  1.000000

# %%
pd.crosstab(titanic.sex,titanic.pclass, values=titanic.fare , aggfunc="sum", margins=True)
# Out:
# pclass           1          2          3         All
# sex
# female   9975.8250  1669.7292  2321.1086  13966.6628
# male     8201.5875  2132.1125  4393.5865  14727.2865
# All     18177.4125  3801.8417  6714.6951  28693.9493

# %%
table_2012=pd.read_csv('C://Users//HP//Documents//Basic_Pandas//table_2012.csv')

# %%
table_2012
# Out:
#    Country  Gold  Silver  Bronze
# 0      USA   147      57      46
# 1      CHN    56      44      28
# 2      GBR    48      30      48
# 3      RUS    47      32      51
# 4      GER    45      28      21
# 5      FRA    30      30      22
# 6      NED    21      29      19
# 7      AUS    19      36      59
# 8      KOR    18      13      32
# 9      MEX    18       5       3
# 10     ITA    16      22      30
# 11     NOR    15       1       1
# 12     CRO    15       4      16
# 13     BRA    14      34      11
# 14     HUN    12       8       6
# 15     NZL     9       3      14
# 16     UKR     9       4      12
# 17     JAM     8       9       8
# 18     JPN     7      44      33
# 19     RSA     6       2       1

# %%
table_2012.melt(id_vars="Country",value_vars=['Gold','Silver','Bronze'],var_name="Medal",value_name="Count")
# Out:
#    Country   Medal  Count
# 0      USA    Gold    147
# 1      CHN    Gold     56
# 2      GBR    Gold     48
# 3      RUS    Gold     47
# 4      GER    Gold     45
# 5      FRA    Gold     30
# 6      NED    Gold     21
# 7      AUS    Gold     19
# 8      KOR    Gold     18
# 9      MEX    Gold     18
# 10     ITA    Gold     16
# 11     NOR    Gold     15
# 12     CRO    Gold     15
# 13     BRA    Gold     14
# 14     HUN    Gold     12
# 15     NZL    Gold      9
# 16     UKR    Gold      9
# 17     JAM    Gold      8
# 18     JPN    Gold      7
# 19     RSA    Gold      6
# 20     USA  Silver     57
# 21     CHN  Silver     44
# 22     GBR  Silver     30
# 23     RUS  Silver     32
# 24     GER  Silver     28
# 25     FRA  Silver     30
# 26     NED  Silver     29
# 27     AUS  Silver     36
# 28     KOR  Silver     13
# 29     MEX  Silver      5
# 30     ITA  Silver     22
# 31     NOR  Silver      1
# 32     CRO  Silver      4
# 33     BRA  Silver     34
# ...
