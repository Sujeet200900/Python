# %% [markdown]
# # Pandas Basics (DataFrame Basics I) Project 1

# %%
#1.Display Options and the methods head() & tail()

# %%
import pandas as pd
import numpy as numpy
import datetime
import psycopg2
import calendar
import gspread as gs
import os
import urllib.request
from PIL import ImageTk, Image  
from PIL import Image

# %%
titanic=pd.read_csv('titanic.csv')

# %%
titanic.head(10)
titanic.tail(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 881         0       3    male  33.0      0      0   7.8958        S  NaN
# 882         0       3  female  22.0      0      0  10.5167        S  NaN
# 883         0       2    male  28.0      0      0  10.5000        S  NaN
# 884         0       3    male  25.0      0      0   7.0500        S  NaN
# 885         0       3  female  39.0      0      5  29.1250        Q  NaN
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
#capital-O
titanic.describe(include= "O")
# Out:
#          sex embarked deck
# count    891      889  203
# unique     2        3    7
# top     male        S    C
# freq     577      644   59

# %%
#2.Built-in Functions, Attributes and Methods with Pandas

# %%
type(titanic)
# Out:
# pandas.core.frame.DataFrame

# %%
len(titanic)
# Out:
# 891

# %%
titanic.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
#note:-Column_Fare_it's change 
round(titanic,0)
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked deck
# 0           0       3    male  22.0      1      0   7.0        S  NaN
# 1           1       1  female  38.0      1      0  71.0        C    C
# 2           1       3  female  26.0      0      0   8.0        S  NaN
# 3           1       1  female  35.0      1      0  53.0        S    C
# 4           0       3    male  35.0      0      0   8.0        S  NaN
# ..        ...     ...     ...   ...    ...    ...   ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0        S  NaN
# 887         1       1  female  19.0      0      0  30.0        S    B
# 888         0       3  female   NaN      1      2  23.0        S  NaN
# 889         1       1    male  26.0      0      0  30.0        C    C
# 890         0       3    male  32.0      0      0   8.0        Q  NaN
#
# [891 rows x 9 columns]

# %%
min(titanic)
# Out:
# 'age'

# %%
#3.Attributes

# %%
titanic.shape
# Out:
# (891, 9)

# %%
titanic.size
# Out:
# 8019

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'deck'],
#       dtype='object')

# %%
titanic.min()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13904\3376850614.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   titanic.min()
# survived         0
# pclass           1
# sex         female
# age           0.42
# sibsp            0
# parch            0
# fare           0.0
# dtype: object

# %%
#MethodsChanging

# %%
titanic.mean().sort_values()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13904\3254614695.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   titanic.mean().sort_values()
# parch        0.381594
# survived     0.383838
# sibsp        0.523008
# pclass       2.308642
# age         29.699118
# fare        32.204208
# dtype: float64

# %%
#Make it easy TAB Completion and Tooltip`

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic.sort_values(['sex','age'], ascending=True)
titanic.sort_values(by= 'age', ascending=True)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 803         1       3    male  0.42      0      1   8.5167        C  NaN
# 755         1       2    male  0.67      1      1  14.5000        S  NaN
# 644         1       3  female  0.75      2      1  19.2583        C  NaN
# 469         1       3  female  0.75      2      1  19.2583        C  NaN
# 78          1       2    male  0.83      0      2  29.0000        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 859         0       3    male   NaN      0      0   7.2292        C  NaN
# 863         0       3  female   NaN      8      2  69.5500        S  NaN
# 868         0       3    male   NaN      0      0   9.5000        S  NaN
# 878         0       3    male   NaN      0      0   7.8958        S  NaN
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
#
# [891 rows x 9 columns]

# %% [markdown]
# # Selecting Columns

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'deck'],
#       dtype='object')

# %%
titanic[['sex','age','fare']]
# Out:
#         sex   age     fare
# 0      male  22.0   7.2500
# 1    female  38.0  71.2833
# 2    female  26.0   7.9250
# 3    female  35.0  53.1000
# 4      male  35.0   8.0500
# ..      ...   ...      ...
# 886    male  27.0  13.0000
# 887  female  19.0  30.0000
# 888  female   NaN  23.4500
# 889    male  26.0  30.0000
# 890    male  32.0   7.7500
#
# [891 rows x 3 columns]

# %%
#Selecting one Column with the dot notation

# %%
titanic.age.equals(titanic['age'])
# Out:
# True

# %% [markdown]
# # pandas-iloc&Loc

# %%
Image.open('C://Users//HP//Documents//Basic_Pandas//Iloc_.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1050x541 at 0x17B494C72B0>

# %%
#1.Selecting Rows with loc (label-based indexing)

# %%
summer=pd.read_csv('summer.csv',index_col=3)

# %%
summer
# Out:
#                      Year    City      Sport                    Athlete  \
# Discipline
# Swimming             1896  Athens   Aquatics              HAJOS, Alfred
# Swimming             1896  Athens   Aquatics           HERSCHMANN, Otto
# Swimming             1896  Athens   Aquatics          DRIVAS, Dimitrios
# Swimming             1896  Athens   Aquatics         MALOKINIS, Ioannis
# Swimming             1896  Athens   Aquatics         CHASAPIS, Spiridon
# ...                   ...     ...        ...                        ...
# Wrestling Freestyle  2012  London  Wrestling         JANIKOWSKI, Damian
# Wrestling Freestyle  2012  London  Wrestling  REZAEI, Ghasem Gholamreza
# Wrestling Freestyle  2012  London  Wrestling             TOTROV, Rustam
# Wrestling Freestyle  2012  London  Wrestling          ALEKSANYAN, Artur
# Wrestling Freestyle  2012  London  Wrestling             LIDBERG, Jimmy
#
#                     Country Gender                       Event   Medal
# Discipline
# ...

# %%
#1.first_row_Frame
summer.iloc[0]

#2.last_row_frame
summer.iloc[-1]

#3. 2nd_row and 3 row
summer.iloc[1:3]


#4. 1st_row and 5 row
summer.iloc[0:5]

#5. last_5_row_in_data
summer.iloc[-5:]

#6. Mid_row_index
summer.iloc[[50,67,70]]
# Out:
#               Year    City    Sport              Athlete Country Gender  \
# Discipline
# Cycling Road  1896  Athens  Cycling     GOEDRICH, August     GER    Men
# Fencing       1896  Athens  Fencing     PYRGOS, Leonidas     GRE    Men
# Fencing       1896  Athens  Fencing  GEORGIADIS, Ioannis     GRE    Men
#
#                              Event   Medal
# Discipline
# Cycling Road  Individual Road Race  Silver
# Fencing              Foil, Masters    Gold
# Fencing           Sabre Individual    Gold

# %%
#2.Selecting Columns with loc (label-based indexing)

# %%
summer
# Out:
#                      Year    City      Sport                    Athlete  \
# Discipline
# Swimming             1896  Athens   Aquatics              HAJOS, Alfred
# Swimming             1896  Athens   Aquatics           HERSCHMANN, Otto
# Swimming             1896  Athens   Aquatics          DRIVAS, Dimitrios
# Swimming             1896  Athens   Aquatics         MALOKINIS, Ioannis
# Swimming             1896  Athens   Aquatics         CHASAPIS, Spiridon
# ...                   ...     ...        ...                        ...
# Wrestling Freestyle  2012  London  Wrestling         JANIKOWSKI, Damian
# Wrestling Freestyle  2012  London  Wrestling  REZAEI, Ghasem Gholamreza
# Wrestling Freestyle  2012  London  Wrestling             TOTROV, Rustam
# Wrestling Freestyle  2012  London  Wrestling          ALEKSANYAN, Artur
# Wrestling Freestyle  2012  London  Wrestling             LIDBERG, Jimmy
#
#                     Country Gender                       Event   Medal
# Discipline
# ...

# %%
#1. Column_index_2nd_first_row_value
summer.iloc[0,2]

#2. first_row_value_by_columns
summer.iloc[0,:5]
summer.iloc[0,:2]

#3.mid_row_value_with_Columns
summer.iloc[34:50,[1,2,3]]
# Out:
#                 City      Sport                    Athlete
# Discipline
# Athletics     Athens  Athletics            GARRETT, Robert
# Athletics     Athens  Athletics             KELLNER, Gyula
# Athletics     Athens  Athletics            LOUIS, Spyridon
# Athletics     Athens  Athletics       VASILAKOS, Kharilaos
# Athletics     Athens  Athletics        DAMASKOS, Evangelos
# Athletics     Athens  Athletics    THEODOROPOULOS, Ioannis
# Athletics     Athens  Athletics       HOYT, William Welles
# Athletics     Athens  Athletics              TYLER, Albert
# Athletics     Athens  Athletics      PAPASIDERIS, Georgios
# Athletics     Athens  Athletics            GARRETT, Robert
# Athletics     Athens  Athletics         GOUSKOS, Miltiadis
# Athletics     Athens  Athletics          PERSAKIS, Ioannis
# Athletics     Athens  Athletics            CONNOLLY, James
# Athletics     Athens  Athletics         TUFFERI, Alexandre
# Cycling Road  Athens    Cycling             BATTEL, Edward
# ...

# %% [markdown]
# # LOC (Content-text_Base_All_Columns & rows)

# %%
summer.loc["Wrestling Freestyle",["Medal","Event"]]
# Out:
#                       Medal     Event
# Discipline
# Wrestling Freestyle    Gold  Wf 120KG
# Wrestling Freestyle  Silver  Wf 120KG
# Wrestling Freestyle  Bronze  Wf 120KG
# Wrestling Freestyle  Bronze  Wf 120KG
# Wrestling Freestyle    Gold  Wf 48 KG
# ...                     ...       ...
# Wrestling Freestyle  Bronze  Wg 84 KG
# Wrestling Freestyle    Gold  Wg 96 KG
# Wrestling Freestyle  Silver  Wg 96 KG
# Wrestling Freestyle  Bronze  Wg 96 KG
# Wrestling Freestyle  Bronze  Wg 96 KG
#
# [72 rows x 2 columns]

# %%
row=list( range(5))+[34,33]
row
# Out:
# [0, 1, 2, 3, 4, 34, 33]

# %%
summer.columns[:3].to_list()+ ["Gender","Medal"]
# Out:
# ['Year', 'City', 'Sport', 'Gender', 'Medal']
